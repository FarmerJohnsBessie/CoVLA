# %% [markdown]
# # CoVLA Data Visualization

# %%
import sys

sys.path.append("/Users/clementzhou/Developer/personal/vla")

# %%
from src import DATA_ROOT
from src.data import load_scene
from src.visualize import plot_sample, plot_BEV

# A list containing all the frames. 
scene = load_scene(DATA_ROOT, "2022-07-14--14-32-55--10_first")

# Load the first frame
figure = plot_sample(scene[200])

plot_BEV(scene[200])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7
#       8 # Load the first frame
#       9 figure = plot_sample(scene[200])
#      10
# ---> 11 plot_BEV(scene[200])
#
# File ~/Developer/personal/vla/src/visualize.py:91, in plot_BEV(sample)
#      89 state = sample["state"]
#      90 trajectory = state["trajectory"]
# ---> 91 plt.plot(torch.flatten(trajectory[:, 0]), torch.flatten(trajectory[:, 1]))
#      92 plt.show()
#
# TypeError: list indices must be integers or slices, not tuple
