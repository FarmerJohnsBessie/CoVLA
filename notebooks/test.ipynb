# %%
import pandas as pd
import sys

# Tell Python where to find your folder (use absolute path)
sys.path.append("/Users/clementzhou/Developer/personal/vla")

from src import data, DATA_ROOT

data.get_scene_ids(DATA_ROOT)
len(data.get_scene_ids(DATA_ROOT))
# Out:
# 50
